# %%
import pandas as pd
file_path = 'C:\\Users\\K Pradeep\\OneDrive\\Documents\\CSV_files\\householdtask3.csv'
df = pd.read_csv(file_path)
print(df.head())
# Out:
#    year  tot_hhs      own  own_wm  own_prop  own_wm_prop  prop_hhs   age  \
# 0  2008  1560859  1087580  574406      69.7         36.8     100.0  35.9
# 1  2008   185965    71256   39405      38.3         21.2      11.9  29.9
# 2  2008   312376   191470   48424      61.3         15.5      20.0  40.0
# 3  2008   312333   196203   84171      62.8         26.9      20.0  34.7
# 4  2008   312240   217657  141318      69.7         45.3      20.0  31.5
#
#    size  income  expenditure  eqv_income  eqv_exp
# 0   2.7   46704        42394       26869    25132
# 1   2.6   23404        25270       14258    15824
# 2   2.3   16747        21145       13402    14408
# 3   2.8   31308        29855       18917    18266
# 4   3.0   49106        46561       26870    24672

# %%
import pandas as pd
import matplotlib.pyplot as plt
# Provide the correct file path where your CSV file is located
file_path = 'C:\\Users\\K Pradeep\\OneDrive\\Documents\\CSV_files\\householdtask3.csv'
# Reading the database
data = pd.read_csv(file_path)
# Scatter plot with 'year' against 'tot_hhs'
plt.scatter(data['year'], data['tot_hhs'])
# Adding Title to the Plot
plt.title("Scatter Plot of year vs total households")
# Setting the X and Y labels
plt.xlabel('Year')
plt.ylabel('Total Households')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
# Provide the correct file path where your CSV file is located
file_path = 'C:\\Users\\K Pradeep\\OneDrive\\Documents\\CSV_files\\householdtask3.csv'
# Reading the database
data = pd.read_csv(file_path)
# Bar chart with 'year' against 'tot_hhs'
plt.bar(data['year'], data['tot_hhs'])
# Adding Title to the Plot
plt.title("Bar Chart of year vs total households")
# Setting the X and Y labels
plt.xlabel('Year')
plt.ylabel('Total Households')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
# Provide the correct file path where your CSV file is located
file_path = 'C:\\Users\\K Pradeep\\OneDrive\\Documents\\CSV_files\\householdtask3.csv'
# Reading the database
data = pd.read_csv(file_path)
# Line chart with 'year' against 'tot_hhs'
plt.plot(data['year'], data['tot_hhs'])
# Adding Title to the Plot
plt.title("Line Chart of year vs total households")
# Setting the X and Y labels
plt.xlabel('Year')
plt.ylabel('Total Households')
plt.show()
